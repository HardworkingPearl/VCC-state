# %% [markdown]
# <a href="https://colab.research.google.com/github/HardworkingPearl/VCC-state/blob/experiments/Experiments/Causal_PFN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install anndata
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.3/172.3 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 14.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 37.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.0/80.0 kB 5.7 MB/s eta 0:00:00
# ...

# %%
data_dir = "/content/drive/MyDrive/VCC/datasets/h5"
mcfaline_dir = f"{data_dir}/mcfaline"
srivatsam_dir = f"{data_dir}/srivatsam"

# %%
# !ls /content/drive/MyDrive/VCC/datasets/h5/mcfaline
# Out:
# GSM7056148_sciPlexGxE_1_preprocessed_cds.h5ad
# GSM7056148_sciPlexGxE_1_sgRNATable_out.txt
# GSM7056149_sciPlexGxE_2_preprocessed_cds.list_A172.h5ad
# GSM7056149_sciPlexGxE_2_preprocessed_cds.list_T98G.h5ad
# GSM7056149_sciPlexGxE_2_preprocessed_cds.list_U87MG.h5ad
# GSM7056150_sciPlex_3_preprocessed_cds.list_GBM4.h5ad
# GSM7056150_sciPlex_3_preprocessed_cds.list_GBM8.h5ad
# GSM7056150_sciPlex_3_preprocessed_cds.list_GSC0131.h5ad
# GSM7056150_sciPlex_3_preprocessed_cds.list_GSC0827.h5ad
# GSM7056151_sciPlex_4_preprocessed_cds.list_A172.h5ad
# GSM7056151_sciPlex_4_preprocessed_cds.list_T98G.h5ad
# GSM7056151_sciPlex_4_preprocessed_cds.list_U87MG.h5ad

# %% [markdown]
# ```
# # Dataset paths - maps dataset names to their directories
# # "/content/state/competition_support_set/{competition_train,k562_gwps,rpe1,jurkat,k562,hepg2}.h5" IFNB,IFNG,INS,
# # Gene knockout/knockdown (CRISPR) Cytokine / PBMC chemical stimulus
# [datasets]
# replogle_h1 = "/content/drive/MyDrive/VCC/datasets/h5/competition_support_set/{competition_train,k562_gwps,rpe1,jurkat,k562,hepg2}.h5"
# # replogle_h1 = "./competition_support_set/{hepg2}.h5"
# # seurat      = "/content/drive/MyDrive/VCC/datasets/h5/jiang/Seurat_object_{TGFB,TNFA}_Perturb_seq.h5ad"
# # pbmcs       = "/content/drive/MyDrive/VCC/datasets/h5/pbmcs/adata_for_cellflow_datasets_with_embeddings.h5ad"
# mcfaline    = "/content/drive/MyDrive/VCC/datasets/h5/mcfaline/{GSM7056148_sciPlexGxE_1_preprocessed_cds,GSM7056149_sciPlexGxE_2_preprocessed_cds.list_A172,GSM7056149_sciPlexGxE_2_preprocessed_cds.list_T98G,GSM7056149_sciPlexGxE_2_preprocessed_cds.list_U87MG,GSM7056150_sciPlex_3_preprocessed_cds.list_GBM8,GSM7056150_sciPlex_3_preprocessed_cds.list_GSC0131,GSM7056150_sciPlex_3_preprocessed_cds.list_GSC0827,GSM7056151_sciPlex_4_preprocessed_cds.list_A172,GSM7056151_sciPlex_4_preprocessed_cds.list_T98G,GSM7056151_sciPlex_4_preprocessed_cds.list_U87MG}.h5ad"
# # srivatsam   = "/content/drive/MyDrive/VCC/datasets/h5/srivatsam/{sciPlex1_cds,sciPlex2_cds,sciPlex3_A549_24hrs,sciPlex3_cds_all_cells,sciPlex3_K562_24hrs,sciPlex3_MCF7_24hrs,sciPlex4_hdaci_cds}.h5ad"
#
# # Training specifications
# # All cell types in a dataset automatically go into training (excluding zeroshot/fewshot overrides)
# [training]
# replogle_h1 = "train"
# # seurat      = "train"
# # pbmcs       = "train"
# mcfaline    = "train"
# # srivatsam   = "train"
#
#
# # Zeroshot specifications - entire cell types go to val or test
# [zeroshot]
# "replogle_h1.hepg2" = "test"
#
# # Fewshot specifications - explicit perturbation lists
# [fewshot]
#
# ```

# %% [markdown]
# GSM7056150_sciPlex_3_preprocessed_cds.list_GSC0131.h5ad
# GSM7056150_sciPlex_3_preprocessed_cds.list_GSC0827.h5ad
# GSM7056151_sciPlex_4_preprocessed_cds.list_A172.h5ad
# GSM7056151_sciPlex_4_preprocessed_cds.list_T98G.h5ad
# GSM7056151_sciPlex_4_preprocessed_cds.list_U87MG.h5ad

# %%
import anndata
adata = anndata.read_h5ad(f"/content/drive/MyDrive/VCC/datasets/h5/pbmcs/adata_for_cellflow_datasets_with_embeddings.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 9697974 × 2000
#     obs: 'sample', 'species', 'gene_count', 'tscp_count', 'mread_count', 'bc1_wind', 'bc2_wind', 'bc3_wind', 'bc1_well', 'bc2_well', 'bc3_well', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'total_counts_MT', 'pct_counts_MT', 'log1p_total_counts_MT', 'donor', 'cytokine', 'treatment', 'cell_type', 'cytokine_family'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'donor_embeddings', 'esm2_embeddings', 'hvg', 'log1p'

# %%
# !git clone https://github.com/HardworkingPearl/VCC-state.git
# %cd VCC-state
# !git switch experiments
# Out:
# Cloning into 'VCC-state'...
# remote: Enumerating objects: 906, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 906 (delta 8), reused 18 (delta 5), pack-reused 871 (from 1)
# Receiving objects: 100% (906/906), 132.03 MiB | 14.77 MiB/s, done.
# Resolving deltas: 100% (318/318), done.
# Updating files: 100% (590/590), done.
# /content/VCC-state
# Branch 'experiments' set up to track remote branch 'experiments' from 'origin'.
# Switched to a new branch 'experiments'

# %%
# !pip install pyreadr
# !pip install tzlocal
# !pip install anndata
# !sudo apt-get update -y || apt-get update -y
# !sudo apt-get install -y build-essential gfortran cmake \
  libxml2-dev libcurl4-openssl-dev libssl-dev \
  libomp-dev libgsl-dev
# !pip install hydra-core
# !pip install lightning
# !pip install geomloss
# !pip install scanpy
# !pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.3/418.3 kB 30.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.3/172.3 kB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 31.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 152.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.0/80.0 kB 9.0 MB/s eta 0:00:00
# ...
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,130 kB]
# Get:5 https://cli.github.com/packages stable/main amd64 Packages [343 B]
# ...

# %%
# !cp /content/drive/MyDrive/VCC/datasets/train_data.npz /content/VCC-state/state/train_data.npz # Note that this is not a evo file, right not it's a workaround to run the code below
# !cp /content/drive/MyDrive/VCC/datasets/target_pca_672.pkl /content/VCC-state/state/target_pca_672.pkl

# %%
data_dir = "/content/drive/MyDrive/VCC/datasets/h5"

# %%
# %cd state
# Out:
# /content/VCC-state/state

# %%
# %env PYTHONPATH=/content/VCC-state/cell-load/src:/content/VCC-state/state/src:$PYTHONPATH
# !python -m src.state tx train \
  data.kwargs.toml_config_path="/content/VCC-state/starter.toml" \
  data.kwargs.num_workers=4 \
  data.kwargs.batch_col="batch_var" \
  data.kwargs.pert_col="target_gene" \
  data.kwargs.cell_type_key="cell_type" \
  data.kwargs.control_pert="non-targeting" \
  data.kwargs.perturbation_features_file="/content/drive/MyDrive/VCC/datasets/h5/competition_support_set/ESM2_pert_features.pt" \
  training.max_steps=32000 \
  training.ckpt_every_n_steps=213 \
  training.val_freq=213 \
  model=causalpfn \
  wandb.tags="causalpfn" \
  output_dir="/content/drive/MyDrive/VCC/experiments/mcfaline" \
  name="causalpfn"
# Out:
# env: PYTHONPATH=/content/VCC-state/cell-load/src:/content/VCC-state/state/src:$PYTHONPATH
# 2025-11-13 19:24:50.805632: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-13 19:24:50.822378: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763061890.843500   28565 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
